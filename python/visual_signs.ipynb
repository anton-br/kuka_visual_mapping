# %%
from PIL import Image, ImageFilter
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = Image.open('./mirea_images/real_images/V01-14-19-1419.jpg')
image = image.resize((224, 224))
filtered = image.filter(ImageFilter.GaussianBlur(radius=5))
im_b = image.filter(ImageFilter.BLUR())
im_x = image.filter(ImageFilter.MaxFilter(size=5))
im_l = image.filter(ImageFilter.MedianFilter(size=11))
im_mm = im_l.filter(ImageFilter.MaxFilter(size=3))
im_k = im_mm.filter(ImageFilter.MinFilter(size=3))
im = im_x.filter(ImageFilter.FIND_EDGES)

# %%
im_k.resize((512, 512))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x17811E69CC0>

# %%
plt.imshow(np.where(np.array(im)/255. > 0.5, 1, 0).astype(float))
